# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# <b>Objectives:<B>
# <ul><li>Data Management Tools: include Relational Databases, NoSQL Databases, and Big Data platforms:</li>
#     <li>Data Integration and Transformation Tools: include Apache Airflow and Apache Kafka. </li>
#     <li>Development Environments: Popular development environments for Data Science include Jupyter Notebooks and RStudio.</li>
# </ul>

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are:
# <ol><li>Python</li><li>R</li><li>Julia</li></ol>

# %% [markdown]
# #### Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# <ol><li>Pandas</li><li>Numpy</li><li>Matplotlib</li><li>Plotly</li></ol>

# %% [markdown]
# <table>
#     <tr></tr><th>Data Science Tools</th></tr>
#     <tr><td>Jupyter Notebook</td></tr>
#     <tr><td>R studio</td></tr>
#     <tr><td>Vs code</td></tr>
# </table>

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# #### This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# #### This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#     Mansour Alhomaydan
